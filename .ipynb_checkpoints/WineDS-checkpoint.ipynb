# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_wine = pd.read_csv('wine.csv', header=None)

# %%
df_wine.columns = [ 'Class label','Alcohol','Malic acid', 'Ash', 'Alcalinity of ash','Magnesium', 'Total phenols', 'Flavanoids', 
                   'Nonflavanoid phenols', 'Proanthocyanins', 'Color intensity', 'Hue', 'OD280/OD315 of diluted wines',
                   'Proline']
print('Class labels', np.unique(df_wine['Class label']))
# Out:
# Class labels [1 2 3]

# %%
df_wine.describe()
# Out:
#        Class label     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count   178.000000  178.000000  178.000000  178.000000         178.000000
# mean      1.938202   13.000618    2.336348    2.366517          19.494944
# std       0.775035    0.811827    1.117146    0.274344           3.339564
# min       1.000000   11.030000    0.740000    1.360000          10.600000
# 25%       1.000000   12.362500    1.602500    2.210000          17.200000
# 50%       2.000000   13.050000    1.865000    2.360000          19.500000
# 75%       3.000000   13.677500    3.082500    2.557500          21.500000
# max       3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# min     70.000000       0.980000    0.340000              0.130000
# 25%     88.000000       1.742500    1.205000              0.270000
# 50%     98.000000       2.355000    2.135000              0.340000
# 75%    107.000000       2.800000    2.875000              0.437500
# max    162.000000       3.880000    5.080000              0.660000
#
#        Proanthocyanins  Color intensity         Hue  \
# count       178.000000       178.000000  178.000000
# mean          1.590899         5.058090    0.957449
# std           0.572359         2.318286    0.228572
# min           0.410000         1.280000    0.480000
# 25%           1.250000         3.220000    0.782500
# 50%           1.555000         4.690000    0.965000
# 75%           1.950000         6.200000    1.120000
# max           3.580000        13.000000    1.710000
#
#        OD280/OD315 of diluted wines      Proline
# count                    178.000000   178.000000
# mean                       2.611685   746.893258
# std                        0.709990   314.907474
# min                        1.270000   278.000000
# 25%                        1.937500   500.500000
# 50%                        2.780000   673.500000
# 75%                        3.170000   985.000000
# max                        4.000000  1680.000000

# %% [markdown]
# Alcalinity, magnesium, color y proline tienen desviaciones estandar grandes, quiza sean elementos que ayuden a inferir

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
X= df_wine[df_wine.columns[1:]]
y= df_wine['Class label']

# %%
mms = MinMaxScaler()
X= mms.fit_transform(X)
df_wine[df_wine.columns[1:]] = X

# %%
df_wine.describe()
# Out:
#        Class label     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count   178.000000  178.000000  178.000000  178.000000         178.000000
# mean      1.938202    0.518584    0.315484    0.538244           0.458502
# std       0.775035    0.213639    0.220780    0.146708           0.172142
# min       1.000000    0.000000    0.000000    0.000000           0.000000
# 25%       1.000000    0.350658    0.170455    0.454545           0.340206
# 50%       2.000000    0.531579    0.222332    0.534759           0.458763
# 75%       3.000000    0.696711    0.462945    0.640374           0.561856
# max       3.000000    1.000000    1.000000    1.000000           1.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean     0.323278       0.453487    0.356386              0.437460
# std      0.155244       0.215811    0.210730              0.234818
# min      0.000000       0.000000    0.000000              0.000000
# 25%      0.195652       0.262931    0.182489              0.264151
# 50%      0.304348       0.474138    0.378692              0.396226
# 75%      0.402174       0.627586    0.534810              0.580189
# max      1.000000       1.000000    1.000000              1.000000
#
#        Proanthocyanins  Color intensity         Hue  \
# count       178.000000       178.000000  178.000000
# mean          0.372523         0.322363    0.388170
# std           0.180555         0.197806    0.185831
# min           0.000000         0.000000    0.000000
# 25%           0.264984         0.165529    0.245935
# 50%           0.361199         0.290956    0.394309
# 75%           0.485804         0.419795    0.520325
# max           1.000000         1.000000    1.000000
#
#        OD280/OD315 of diluted wines     Proline
# count                    178.000000  178.000000
# mean                       0.491460    0.334446
# std                        0.260070    0.224613
# min                        0.000000    0.000000
# 25%                        0.244505    0.158702
# 50%                        0.553114    0.282097
# 75%                        0.695971    0.504280
# max                        1.000000    1.000000

# %%
wine_byclass = df_wine.groupby(by='Class label')

# %%
means = wine_byclass.mean()
temp = pd.DataFrame(means)

# %%
temp.plot.bar(figsize=(16,6), legend=True)

# %%
[temp.plot.bar(y = c) for c in temp.columns]
# Out:
# [<matplotlib.axes._subplots.AxesSubplot at 0x19e550efdd8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19e5518d5f8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19e55422630>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19e5543b400>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19e554d3470>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19e555bd0b8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19e55647278>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19e556ee588>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19e55755160>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19e557a7f28>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19e5589d278>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19e5593fb00>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19e55979208>]

# %% [markdown]
# Alcohol, Alcalinity of ash, magnesium, total phenols, flavanoids, nonflavanoid phenols, Proanthocyanins, Color intensity,OD280/OD315 of diluted wines and proline are important features that can help to predict correctly. maybe magnesium and proline can no be so important

# %%
def scatterPlot(X,Y,df):
    color = {1:'red', 2:'blue', 3:'green'}
    fig = plt.figure()
    for i in range(1,4):
        plt.scatter(df[df['Class label']==i][X], df[df['Class label']==i][Y], c= color[i])
        plt.xlabel(X)
        plt.ylabel(Y)
    plt.show()

# %%
[scatterPlot(c,'Alcohol', df_wine) for c in df_wine.columns[2:]]
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None]

# %%
[df_wine.plot.scatter(x=c, y='Alcohol') for c in df_wine.columns[2:]]
# Out:
# [<matplotlib.axes._subplots.AxesSubplot at 0x19e5a67da90>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19e5a74ba20>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19e5a7d0240>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19e5c1947f0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19e5c194f98>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19e5c1994a8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19e5c32b0b8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19e5c39d7f0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19e5c408e80>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19e5c4af7f0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19e5c5282e8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x19e5c1ae898>]

# %% [markdown]
# ##
